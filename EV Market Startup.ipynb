# %%
import pandas as pd
import numpy as np

# %%
df_loc=pd.read_csv("EV_India.csv")

# %%
df_loc
# Out:
#     Sr. No.                State Name Total Electric Vehicle  \
# 0         1  Andaman & Nicobar Island                    162
# 1         2             Andra Pradesh                    NaN
# 2         3         Arunachal Pradesh                     20
# 3         4                     Assam                  64766
# 4         5                     Bihar                  83335
# 5         6                Chandigarh                   2812
# 6         7              Chhattisgarh                  20966
# 7         8                     Delhi               1,56,393
# 8         9                       Goa                   3870
# 9        10                   Gujarat                  45272
# 10       11                   Haryana                  37035
# 11       12          Himachal Pradesh                   1175
# 12       13         Jammu and Kashmir                   2941
# 13       14                 Jharkhand                  16811
# ...

# %%
df_loc=df_loc.drop(['Sr. No.','Total Non-Electric Vehicle','Total'],axis=1)

# %%
df_loc
# Out:
#                   State Name Total Electric Vehicle
# 0   Andaman & Nicobar Island                    162
# 1              Andra Pradesh                    NaN
# 2          Arunachal Pradesh                     20
# 3                      Assam                  64766
# 4                      Bihar                  83335
# 5                 Chandigarh                   2812
# 6               Chhattisgarh                  20966
# 7                      Delhi               1,56,393
# 8                        Goa                   3870
# 9                    Gujarat                  45272
# 10                   Haryana                  37035
# 11          Himachal Pradesh                   1175
# 12         Jammu and Kashmir                   2941
# 13                 Jharkhand                  16811
# 14                 Karnataka               1,20,532
# 15                    Kerala                  30775
# 16                    Ladakh                     26
# ...

# %%
n=df_loc.iloc[:,-1].values

# %%
print(n)
# Out:
# ['162' nan '20' '64766' '83335' '2812' '20966' '1,56,393' '3870' '45272'
#  '37035' '1175' '2941' '16811' '1,20,532' '30775' '26' nan nan '1,16,646'
#  '586' '49' '21' '58' '23371' '2149' '14804' '81338' '21' '82051' nan
#  '9262' '183' '31008' '3,37,180' '48767']

# %%
import math
dff=[]
for i in n:
    z=0
    n1=[]
    if(i=='nan'):
        n1.append(0)
    elif(type(i)==float):
        n1.append(0)
    else:
        for j in i:
            if(j!=','):
                n1.append(j)
        l=len(n1)-1
        for k in n1:
            z+=int(k)*math.pow(10,l)
            l=l-1
    dff.append(z)

# %%
dff
# Out:
# [162.0,
#  0,
#  20.0,
#  64766.0,
#  83335.0,
#  2812.0,
#  20966.0,
#  156393.0,
#  3870.0,
#  45272.0,
#  37035.0,
#  1175.0,
#  2941.0,
#  16811.0,
#  120532.0,
#  30775.0,
#  26.0,
#  0,
#  0,
#  116646.0,
#  586.0,
#  49.0,
#  21.0,
#  58.0,
#  23371.0,
#  2149.0,
#  14804.0,
#  81338.0,
#  21.0,
#  82051.0,
#  0,
#  9262.0,
#  183.0,
#  31008.0,
#  337180.0,
#  48767.0]

# %%
df_loc['Total Electric Vehicle']=dff

# %%
df_loc
# Out:
#                   State Name  Total Electric Vehicle
# 0   Andaman & Nicobar Island                   162.0
# 1              Andra Pradesh                     0.0
# 2          Arunachal Pradesh                    20.0
# 3                      Assam                 64766.0
# 4                      Bihar                 83335.0
# 5                 Chandigarh                  2812.0
# 6               Chhattisgarh                 20966.0
# 7                      Delhi                156393.0
# 8                        Goa                  3870.0
# 9                    Gujarat                 45272.0
# 10                   Haryana                 37035.0
# 11          Himachal Pradesh                  1175.0
# 12         Jammu and Kashmir                  2941.0
# 13                 Jharkhand                 16811.0
# 14                 Karnataka                120532.0
# 15                    Kerala                 30775.0
# 16                    Ladakh                    26.0
# ...

# %%
df_loc.sort_values(by=['Total Electric Vehicle'], ascending=False)
# Out:
#                   State Name  Total Electric Vehicle
# 34             Uttar Pradesh                337180.0
# 7                      Delhi                156393.0
# 14                 Karnataka                120532.0
# 19               Maharashtra                116646.0
# 4                      Bihar                 83335.0
# 29                Tamil Nadu                 82051.0
# 27                 Rajasthan                 81338.0
# 3                      Assam                 64766.0
# 35               West Bengal                 48767.0
# 9                    Gujarat                 45272.0
# 10                   Haryana                 37035.0
# 33               Uttarakhand                 31008.0
# 15                    Kerala                 30775.0
# 24                    Odisha                 23371.0
# 6               Chhattisgarh                 20966.0
# 13                 Jharkhand                 16811.0
# 26                    Punjab                 14804.0
# ...

# %%
from matplotlib import pyplot as plt
plt1=plt.figure(figsize=(15,15))
plt.bar(df_loc.iloc[:,0],df_loc.iloc[:,1])
plt.xticks(rotation =90)
plt.show()

# %% [markdown]
# From the above dataframe we can say that the UttarPradesh State has more number of Electric Vehicles followed by Delhi,Karnataka,Maharastra.Starting an EV startup from here will be more profitable compared to other states.

# %%
import pandas as pd
df_w=pd.read_excel("Ev Sales.xlsx")

# %%
df_w
# Out:
#          YEAR     2 W    3 W   4 W  BUS   TOTAL
# 0  2017-04-01      96   4748   198    0    5042
# 1  2017-05-01      91   6720   215    2    7028
# 2  2017-06-01     137   7178   149    1    7465
# 3  2017-07-01     116   8775   120    0    9011
# 4  2017-08-01      99   8905   137    0    9141
# ..        ...     ...    ...   ...  ...     ...
# 69 2023-01-01   64649  34308  3490   98  102545
# 70 2023-02-01   66033  35995  4850   99  106977
# 71 2023-03-01   86194  45225  8852   89  140360
# 72 2023-04-01   66755  38016  6193   84  111048
# 73 2023-05-01  105154  44615  7736  283  157788
#
# [74 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
plt.plot(df_w.iloc[:,0],df_w.iloc[:,-1])

# %%
df_w=df_w.drop(['TOTAL'],axis=1)

# %%
df_w
# Out:
#          YEAR     2 W    3 W   4 W  BUS
# 0  2017-04-01      96   4748   198    0
# 1  2017-05-01      91   6720   215    2
# 2  2017-06-01     137   7178   149    1
# 3  2017-07-01     116   8775   120    0
# 4  2017-08-01      99   8905   137    0
# ..        ...     ...    ...   ...  ...
# 69 2023-01-01   64649  34308  3490   98
# 70 2023-02-01   66033  35995  4850   99
# 71 2023-03-01   86194  45225  8852   89
# 72 2023-04-01   66755  38016  6193   84
# 73 2023-05-01  105154  44615  7736  283
#
# [74 rows x 5 columns]

# %%
df_w.sum(axis=0)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_19148\2275755012.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_w.sum(axis=0)
# 2 W    1253466
# 3 W    1099000
# 4 W      94170
# BUS       6091
# dtype: int64

# %%
y=df_w.sum(axis=0)
# Out:
# C:\Users\navee\AppData\Local\Temp\ipykernel_19148\322857507.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   y=df_w.sum(axis=0)

# %%
x=['2W','3W','4W','BUS']

# %%
from matplotlib import pyplot as plt
plt.bar(x,y)
plt.show()

# %% [markdown]
# from the graph we can say that the 2 and 3 wheel electric vehicles are popular and demanding.

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.head()
# Out:
#    Age  Gender Education Level          Job Title  Years of Experience  Salary
# 0   32    Male      Bachelor's  Software Engineer                  5.0   90000
# 1   28  Female        Master's       Data Analyst                  3.0   65000
# 2   45    Male             PhD     Senior Manager                 15.0  150000
# 3   36  Female      Bachelor's    Sales Associate                  7.0   60000
# 4   52    Male        Master's           Director                 20.0  200000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6698 entries, 0 to 6697
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6698 non-null   int64
#  1   Gender               6698 non-null   object
#  2   Education Level      6698 non-null   object
#  3   Job Title            6698 non-null   object
#  4   Years of Experience  6698 non-null   float64
#  5   Salary               6698 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 314.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df['Education Level']=le.fit_transform(df['Education Level'])

# %%
df.head()
# Out:
#    Age  Gender  Education Level          Job Title  Years of Experience  \
# 0   32       1                0  Software Engineer                  5.0
# 1   28       0                3       Data Analyst                  3.0
# 2   45       1                5     Senior Manager                 15.0
# 3   36       0                0    Sales Associate                  7.0
# 4   52       1                3           Director                 20.0
#
#    Salary
# 0   90000
# 1   65000
# 2  150000
# 3   60000
# 4  200000

# %%
df=df.drop(['Job Title','Years of Experience'],axis=1)

# %%
df.head()
# Out:
#    Age  Gender  Education Level  Salary
# 0   32       1                0   90000
# 1   28       0                3   65000
# 2   45       1                5  150000
# 3   36       0                0   60000
# 4   52       1                3  200000

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Salary'], dtype='object')

# %%
col=['Age', 'Gender', 'Education Level', 'Salary']

# %%
df.describe()
# Out:
#                Age       Gender  Education Level         Salary
# count  6698.000000  6698.000000      6698.000000    6698.000000
# mean     33.623022     0.552254         2.561809  115329.253061
# std       7.615784     0.501485         1.815719   52789.792507
# min      21.000000     0.000000         0.000000     350.000000
# 25%      28.000000     0.000000         1.000000   70000.000000
# 50%      32.000000     1.000000         2.000000  115000.000000
# 75%      38.000000     1.000000         4.000000  160000.000000
# max      62.000000     2.000000         6.000000  250000.000000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_x=sc.fit_transform(df.iloc[:,[0,2,3]])

# %%
print(sc_x)
# Out:
# [[-0.2131288  -1.41101158 -0.47984928]
#  [-0.73839298  0.24134967 -0.95346104]
#  [ 1.49397978  1.34292384  0.65681894]
#  ...
#  [-0.47576089 -0.8602245  -1.14290574]
#  [ 1.62529582  0.79213676  0.46737423]
#  [-1.00102507 -0.30943741 -1.52179515]]

# %%
df['Age']=sc_x[:,0]

# %%
df['Education Level']=sc_x[:,1]

# %%
df['Salary']=sc_x[:,2]

# %%
df.head()
# Out:
#         Age  Gender  Education Level    Salary
# 0 -0.213129       1        -1.411012 -0.479849
# 1 -0.738393       0         0.241350 -0.953461
# 2  1.493980       1         1.342924  0.656819
# 3  0.312135       0        -1.411012 -1.048183
# 4  2.413192       1         0.241350  1.604042

# %%
df.describe()
# Out:
#                 Age       Gender  Education Level        Salary
# count  6.698000e+03  6698.000000     6.698000e+03  6.698000e+03
# mean  -6.789301e-17     0.552254    -2.121656e-17 -6.789301e-17
# std    1.000075e+00     0.501485     1.000075e+00  1.000075e+00
# min   -1.657605e+00     0.000000    -1.411012e+00 -2.178221e+00
# 25%   -7.383930e-01     0.000000    -8.602245e-01 -8.587387e-01
# 50%   -2.131288e-01     1.000000    -3.094374e-01 -6.237525e-03
# 75%    5.747675e-01     1.000000     7.921368e-01  8.462636e-01
# max    3.726353e+00     2.000000     1.893711e+00  2.551266e+00

# %%
from sklearn.decomposition import PCA
pca=PCA()
df_pca=pca.fit_transform(df)

# %%
df_pca
# Out:
# array([[-1.13555506,  0.99231781,  0.35952291,  0.25233387],
#        [-0.9113513 , -0.92632742,  0.00550821, -0.35898848],
#        [ 2.01866084, -0.34098154,  0.58396121,  0.36747323],
#        ...,
#        [-1.43707148, -0.01926778,  0.41772128, -0.58096157],
#        [ 1.69947515,  0.070784  ,  0.85375031,  0.25664413],
#        [-1.69677878, -0.78861898,  0.24656944, -0.39607259]])

# %%
c_pca=['PC1','PC2','PC3','PC4']
variance=pca.explained_variance_ratio_
sd=np.sqrt(pca.explained_variance_)
c_v=np.cumsum(pca.explained_variance_ratio_)
print("Variance")
print(variance)
print()
print("Standard Deviation")
print(sd)
print()
print("Cumulative Variance")
print(c_v)
# Out:
# Variance
# [0.666331   0.17863788 0.08233519 0.07269593]
#
# Standard Deviation
# [1.47202763 0.76218032 0.5174444  0.48621236]
#
# Cumulative Variance
# [0.666331   0.84496889 0.92730407 1.        ]

# %%
pos=pd.DataFrame(sd,index=c_pca,columns=['Standard Deviation'])

# %%
pos
# Out:
#      Standard Deviation
# PC1            1.472028
# PC2            0.762180
# PC3            0.517444
# PC4            0.486212

# %%
pos['Variance']=variance
pos['Cumulative Variance']=c_v

# %%
pos
#From this we can say that PC1 and PC2 combinely has 85% of information
# Out:
#      Standard Deviation  Variance  Cumulative Variance
# PC1            1.472028  0.666331             0.666331
# PC2            0.762180  0.178638             0.844969
# PC3            0.517444  0.082335             0.927304
# PC4            0.486212  0.072696             1.000000

# %%
r=pca.components_.T

# %%
pos1=pd.DataFrame(r,index=col,columns=c_pca)

# %%
pos1
# Out:
#                       PC1       PC2       PC3       PC4
# Age              0.611602  0.271609  0.719532 -0.185596
# Gender           0.033459  0.188275  0.150670  0.969913
# Education Level  0.520796 -0.834492 -0.087035  0.157542
# Salary           0.594639  0.440913 -0.672308 -0.001662

# %%
plt1=plt.figure(figsize=(10,10))
plt.scatter(df_pca[:, 0], df_pca[:, 1], color='grey',s=8)
for i, label in enumerate(col):
    plt.annotate(label, (r[i, 0], r[i, 1]),color='blue',size=10)
    plt.arrow(0, 0, r[i, 0], r[i, 1],head_width=0.05, head_length=0.05,color='red')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA Projection')
plt.show()

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,11):
    model=KMeans(n_clusters=i)
    model.fit(df)
    wcss.append(model.inertia_)
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(range(1,11),wcss)
plt.show()

# %%
num_of_clusters=4
model=KMeans(n_clusters=4)
model.fit(df)
y=model.predict(df)
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
seg_df=pd.DataFrame(df,columns=col)

# %%
seg_df.head()
# Out:
#         Age  Gender  Education Level    Salary
# 0 -0.213129       1        -1.411012 -0.479849
# 1 -0.738393       0         0.241350 -0.953461
# 2  1.493980       1         1.342924  0.656819
# 3  0.312135       0        -1.411012 -1.048183
# 4  2.413192       1         0.241350  1.604042

# %%
seg_df['cluster']=y

# %%
seg_df.head()
# Out:
#         Age  Gender  Education Level    Salary  cluster
# 0 -0.213129       1        -1.411012 -0.479849        2
# 1 -0.738393       0         0.241350 -0.953461        1
# 2  1.493980       1         1.342924  0.656819        3
# 3  0.312135       0        -1.411012 -1.048183        1
# 4  2.413192       1         0.241350  1.604042        3

# %%
seg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6698 entries, 0 to 6697
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              6698 non-null   float64
#  1   Gender           6698 non-null   int32
#  2   Education Level  6698 non-null   float64
#  3   Salary           6698 non-null   float64
#  4   cluster          6698 non-null   int32
# dtypes: float64(3), int32(2)
# memory usage: 209.4 KB

# %%
df.head()
# Out:
#         Age  Gender  Education Level    Salary
# 0 -0.213129       1        -1.411012 -0.479849
# 1 -0.738393       0         0.241350 -0.953461
# 2  1.493980       1         1.342924  0.656819
# 3  0.312135       0        -1.411012 -1.048183
# 4  2.413192       1         0.241350  1.604042

# %%
x=df.iloc[:,[0,3]].values

# %%
model.fit(x)
y=model.predict(x)
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='yellow',label='cluster1')
plt.scatter(model.cluster_centers_[0,0],model.cluster_centers_[0,1],s=100,c='black')
plt.scatter(x[y==1,0],x[y==1,1],color='red',label='cluster2')
plt.scatter(model.cluster_centers_[1,0],model.cluster_centers_[1,1],s=100,c='black')
plt.scatter(x[y==2,0],x[y==2,1],color='green',label='cluster3')
plt.scatter(model.cluster_centers_[2,0],model.cluster_centers_[2,1],s=100,c='black')
plt.scatter(x[y==3,0],x[y==3,1],color='blue',label='cluster4')
plt.scatter(model.cluster_centers_[3,0],model.cluster_centers_[3,1],s=100,c='black')
plt.xlabel("age")
plt.ylabel("salary")
plt.legend()
plt.show()

# %%
x=df.iloc[:,[2,3]].values
model.fit(x)
y=model.predict(x)
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='yellow',label='cluster1')
plt.scatter(model.cluster_centers_[0,0],model.cluster_centers_[0,1],s=100,c='black')
plt.scatter(x[y==1,0],x[y==1,1],color='red',label='cluster2')
plt.scatter(model.cluster_centers_[1,0],model.cluster_centers_[1,1],s=100,c='black')
plt.scatter(x[y==2,0],x[y==2,1],color='green',label='cluster3')
plt.scatter(model.cluster_centers_[2,0],model.cluster_centers_[2,1],s=100,c='black')
plt.scatter(x[y==3,0],x[y==3,1],color='blue',label='cluster4')
plt.scatter(model.cluster_centers_[3,0],model.cluster_centers_[3,1],s=100,c='black')
plt.xlabel("Education Level")
plt.ylabel("salary")
plt.legend()
plt.show()

# %%
x=df.iloc[:,[1,3]].values
model.fit(x)
y=model.predict(x)
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.scatter(x[y==0,0],x[y==0,1],color='yellow',label='cluster1')
plt.scatter(model.cluster_centers_[0,0],model.cluster_centers_[0,1],s=100,c='black')
plt.scatter(x[y==1,0],x[y==1,1],color='red',label='cluster2')
plt.scatter(model.cluster_centers_[1,0],model.cluster_centers_[1,1],s=100,c='black')
plt.scatter(x[y==2,0],x[y==2,1],color='green',label='cluster3')
plt.scatter(model.cluster_centers_[2,0],model.cluster_centers_[2,1],s=100,c='black')
plt.scatter(x[y==3,0],x[y==3,1],color='blue',label='cluster4')
plt.scatter(model.cluster_centers_[3,0],model.cluster_centers_[3,1],s=100,c='black')
plt.xlabel("Gender")
plt.ylabel("salary")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
model_k=KMeans(n_clusters=4)
model_k.fit(df)
labels = model_k.labels_

df_mean = df.groupby(labels).mean()
plt1=plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.barh(range(df_mean.shape[1]), df_mean.iloc[0])
plt.title('Component 1')
plt.ylabel('Variable')
plt.xlabel('Proportion')
plt.yticks(range(0,4),col)

plt.subplot(2,2,2)
plt.barh(range(df_mean.shape[1]), df_mean.iloc[1])
plt.title('Component 2')
plt.yticks(range(0,4),col)
plt.xlabel('Proportion')
plt.ylabel('Variable')

plt.subplot(2,2,3)
plt.barh(range(df_mean.shape[1]), df_mean.iloc[2])
plt.title('Component 3')
plt.yticks(range(0,4),col)
plt.ylabel('Variable')
plt.xlabel('Proportion')

plt.subplot(2,2,4)
plt.barh(range(df_mean.shape[1]), df_mean.iloc[3])
plt.title('Component 4')
plt.yticks(range(0,4),col)
plt.xlabel('Proportion')
plt.ylabel('Variable')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pca = PCA(n_components=2)
df1_pca = pca.fit_transform(df)
model = KMeans(n_clusters=4)
model.fit(df1_pca)
pred=model.predict(df1_pca)

c=['blue','yellow','green','black']

plt1=plt.figure(figsize=(10,10))
for i in range(4):
    plt.scatter(df1_pca[pred == i,0],df1_pca[pred == i,1],c=c[i])
    
    
for i, label in enumerate(col):
    plt.annotate(label, (r[i, 0], r[i, 1]),color='blue',size=10)
    plt.arrow(0, 0, r[i, 0], r[i, 1],head_width=0.05, head_length=0.05,color='red')
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.show()
# Out:
# C:\Users\navee\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
seg_df.head()
# Out:
#         Age  Gender  Education Level    Salary  cluster
# 0 -0.213129       1        -1.411012 -0.479849        2
# 1 -0.738393       0         0.241350 -0.953461        1
# 2  1.493980       1         1.342924  0.656819        3
# 3  0.312135       0        -1.411012 -1.048183        1
# 4  2.413192       1         0.241350  1.604042        3

# %%
seg_df.head()
# Out:
#         Age  Gender  Education Level    Salary  cluster
# 0 -0.213129       1        -1.411012 -0.479849        2
# 1 -0.738393       0         0.241350 -0.953461        1
# 2  1.493980       1         1.342924  0.656819        3
# 3  0.312135       0        -1.411012 -1.048183        1
# 4  2.413192       1         0.241350  1.604042        3

# %%
sc_inv_x=sc.inverse_transform(sc_x)

# %%
print(sc_inv_x)
# Out:
# [[3.2e+01 0.0e+00 9.0e+04]
#  [2.8e+01 3.0e+00 6.5e+04]
#  [4.5e+01 5.0e+00 1.5e+05]
#  ...
#  [3.0e+01 1.0e+00 5.5e+04]
#  [4.6e+01 4.0e+00 1.4e+05]
#  [2.6e+01 2.0e+00 3.5e+04]]

# %%
seg_df['Age']=sc_inv_x[:,0]

# %%
seg_df['Education Level']=sc_inv_x[:,1]

# %%
seg_df['Salary']=sc_inv_x[:,2]

# %%
seg_df.head()
# Out:
#     Age  Gender  Education Level    Salary  cluster
# 0  32.0       1              0.0   90000.0        2
# 1  28.0       0              3.0   65000.0        1
# 2  45.0       1              5.0  150000.0        3
# 3  36.0       0              0.0   60000.0        1
# 4  52.0       1              3.0  200000.0        3

# %%
age=seg_df.groupby('cluster')['Age'].mean()
age = age.to_frame().reset_index()
age
# Out:
#    cluster        Age
# 0        0  33.175186
# 1        1  27.567170
# 2        2  33.598013
# 3        3  46.043513

# %%
age=seg_df.groupby('cluster')['Age'].min()
age = age.to_frame().reset_index()
age
# Out:
#    cluster   Age
# 0        0  23.0
# 1        1  21.0
# 2        2  24.0
# 3        3  37.0

# %%
age=seg_df.groupby('cluster')['Age'].max()
age = age.to_frame().reset_index()
age
# Out:
#    cluster   Age
# 0        0  45.0
# 1        1  40.0
# 2        2  51.0
# 3        3  62.0

# %%
Gender=seg_df.groupby('cluster')['Gender'].mean()
Gender = Gender.to_frame().reset_index()
Gender
# Out:
#    cluster    Gender
# 0        0  0.411076
# 1        1  0.522662
# 2        2  0.663053
# 3        3  0.722310

# %%
Salary=seg_df.groupby('cluster')['Salary'].mean()
Salary = Salary.to_frame().reset_index()
Salary
# Out:
#    cluster         Salary
# 0        0  129544.551651
# 1        1   60101.954675
# 2        2  141333.478771
# 3        3  178437.358386

# %%
Salary=seg_df.groupby('cluster')['Salary'].min()
Salary = Salary.to_frame().reset_index()
Salary
# Out:
#    cluster    Salary
# 0        0   49000.0
# 1        1     350.0
# 2        2   65000.0
# 3        3  120000.0

# %%
Salary=seg_df.groupby('cluster')['Salary'].max()
Salary = Salary.to_frame().reset_index()
Salary
# Out:
#    cluster    Salary
# 0        0  198000.0
# 1        1  110000.0
# 2        2  215000.0
# 3        3  250000.0
